# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import PowerTransformer

# %% [markdown]
# nie onehot tylko category
#
# df['kolumna'] = df['kolumna'].astype('category')

# %%
df = pd.read_csv('student_dropout.csv')

# %%
pd.set_option('display.max_columns', None)

# %%
df.describe()
# Out:
#        Marital status  Application mode  Application order       Course  \
# count     4406.000000       4424.000000        4424.000000  4424.000000
# mean         1.179301         18.669078           1.727848  8856.642631
# std          0.606876         17.484682           1.313793  2063.566416
# min          1.000000          1.000000           0.000000    33.000000
# 25%          1.000000          1.000000           1.000000  9085.000000
# 50%          1.000000         17.000000           1.000000  9238.000000
# 75%          1.000000         39.000000           2.000000  9556.000000
# max          6.000000         57.000000           9.000000  9991.000000
#
#        Daytime/evening attendance\t  Previous qualification  \
# count                   4424.000000             4424.000000
# mean                       0.890823                4.577758
# std                        0.311897               10.216592
# min                        0.000000                1.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4424 entries, 0 to 4423
# Data columns (total 37 columns):
#  #   Column                                          Non-Null Count  Dtype
# ---  ------                                          --------------  -----
#  0   Marital status                                  4406 non-null   float64
#  1   Application mode                                4424 non-null   int64
#  2   Application order                               4424 non-null   int64
#  3   Course                                          4424 non-null   int64
#  4   Daytime/evening attendance	                     4424 non-null   int64
#  5   Previous qualification                          4424 non-null   int64
#  6   Previous qualification (grade)                  4424 non-null   float64
#  7   Nacionality                                     4424 non-null   int64
#  8   Mother's qualification                          4420 non-null   float64
# ...

# %%
df['Gender']
# Out:
# 0       20.0
# 1       19.0
# 2       19.0
# 3       20.0
# 4       45.0
#         ...
# 4419    19.0
# 4420    18.0
# 4421    30.0
# 4422    20.0
# 4423    22.0
# Name: Gender, Length: 4424, dtype: float64

# %%
df['Age at enrollment']
# Out:
# 0       20.0
# 1       19.0
# 2       19.0
# 3       20.0
# 4       45.0
#         ...
# 4419    19.0
# 4420    18.0
# 4421    30.0
# 4422    20.0
# 4423    22.0
# Name: Age at enrollment, Length: 4424, dtype: float64

# %%
df.drop(columns = ['Gender'], inplace = True)

# %%
df['Mother\'s occupation'].value_counts()
# Out:
# Mother's occupation
# Unskilled Workers                                                                                             1577
# Administrative staff                                                                                           817
# Personal Services, Security and Safety Workers and Sellers                                                     530
# Intermediate Level Technicians and Professions                                                                 351
# Specialists in Intellectual and Scientific Activities                                                          318
# Skilled Workers in Industry, Construction and Craftsmen                                                        272
# Student                                                                                                        144
# Representatives of the Legislative Power and Executive Bodies, Directors, Directors and Executive Managers     102
# ...

# %%
df['Age at enrollment'].value_counts()
# Out:
# Age at enrollment
#  18.00     1031
#  19.00      909
#  20.00      597
#  21.00      322
#  22.00      173
#  24.00      130
#  23.00      106
#  26.00       94
#  25.00       93
#  27.00       91
#  28.00       82
#  29.00       65
#  32.00       61
#  34.00       60
#  31.00       54
#  30.00       49
#  35.00       48
#  33.00       45
#  37.00       42
#  39.00       38
#  36.00       35
#  41.00       31
#  38.00       29
#  43.00       25
#  40.00       23
#  45.00       22
#  44.00       21
#  47.00       18
#  50.00       16
#  49.00       13
#  42.00       13
#  46.00       12
#  48.00       11
#  54.00        7
#  51.00        7
#  53.00        7
#  55.00        5
#  17.00        5
#  52.00        4
#  58.00        3
#  59.00        3
#  60.00        2
#  57.00        2
#  70.00        1
#  61.00        1
#  62.00        1
#  118.00       1
#  0.22         1
#  0.20         1
# -18.00        1
# -20.00        1
#  123.00       1
# Name: count, dtype: int64

# %%
df.loc[(df['Age at enrollment'] < 17) | (df['Age at enrollment'] > 70), 'Age at enrollment'] = np.nan

# %%
sns.set_theme(style="whitegrid", palette="muted")

# %%
plt.figure(figsize=(8, 5))
sns.countplot(data=df, x='Target', palette='Set2')
plt.title('Rozkład zmiennej docelowej')
plt.ylabel('Liczba studentów')
plt.show()
# Out:
# /tmp/ipykernel_2779/1885493831.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x='Target', palette='Set2')

# %%
plt.figure(figsize=(8, 5))
sns.barplot(data=df, x='Target', y='Curricular units 1st sem (grade)', palette='Set2', errorbar=None)
plt.title('Średnia ocen po 1 semestrze a status studenta')
plt.ylabel('Średnia ocen')
plt.show()
# Out:
# /tmp/ipykernel_2779/288902114.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=df, x='Target', y='Curricular units 1st sem (grade)', palette='Set2', errorbar=None)

# %%
plt.figure(figsize=(8, 5))
sns.countplot(data=df, x='Scholarship holder', hue='Target', palette='Set2')
plt.title('Posiadanie stypendium a status studenta')
plt.xlabel('Czy posiada stypendium?')
plt.ylabel('Liczba studentów')
plt.show()

# %%
plt.figure(figsize=(8, 5))
sns.histplot(data=df, x='Age at enrollment', hue='Target', multiple='stack', palette='Set2', bins=15)
plt.title('Rozkład wieku studentów a rezygnacje')
plt.xlabel('Wiek w momencie rozpoczęcia studiów')
plt.ylabel('Liczba studentów')
plt.show()

# %%
plt.figure(figsize=(8, 5))
sns.countplot(data=df, x='Debtor', hue='Target', palette='Set2')
plt.title('Posiadanie zadłużenia a status studenta')
plt.xlabel('Czy student jest dłużnikiem?')
plt.ylabel('Liczba studentów')
plt.show()

# %%
plt.figure(figsize=(7, 5))
sns.boxplot(data=df, x='Target', y='Unemployment rate', palette='Set2')
plt.title('Wpływ stopy bezrobocia na status studenta')
plt.xlabel('Status studenta')
plt.ylabel('Stopa bezrobocia (%)')
plt.show()
# Out:
# /tmp/ipykernel_2779/613082562.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df, x='Target', y='Unemployment rate', palette='Set2')

# %%
plt.figure(figsize=(7, 5))
sns.boxplot(data=df, x='Target', y='GDP', palette='Set2')
plt.title('Wpływ PKB na status studenta')
plt.xlabel('Status studenta')
plt.ylabel('Wskaźnik PKB')
plt.show()
# Out:
# /tmp/ipykernel_2779/1657196434.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df, x='Target', y='GDP', palette='Set2')

# %%
plt.figure(figsize=(7, 5))
sns.boxplot(data=df, x='Target', y='Inflation rate', palette='Set2')
plt.title('Wpływ inflacji na status studenta')
plt.xlabel('Status studenta')
plt.ylabel('Stopa inflacji (%)')
plt.show()
# Out:
# /tmp/ipykernel_2779/181417506.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df, x='Target', y='Inflation rate', palette='Set2')

# %%
columns_to_encode = [
    'Marital status',
    'Application mode',
    'Application order',
    'Course',
    'Previous qualification',
    'Nacionality',
    "Mother's qualification",
    "Father's qualification",
    "Mother's occupation",
    "Father's occupation"
]

# %%
for i in columns_to_encode:
  df[i] = df[i].astype('category')

# %%
df.columns = df.columns.str.strip()

# %%
bool_columns = [
    'Daytime/evening attendance',
    'Displaced',
    'Educational special needs',
    'Debtor',
    'Tuition fees up to date',
    'Scholarship holder',
    'International'
]

# %%
mapping = {'yes': 1, 'no': 0}

# %%
for col in bool_columns:
    if col in df.columns:
        df[col] = df[col].replace(mapping)
        df[col] = pd.to_numeric(df[col]).astype(int)
# Out:
# /tmp/ipykernel_2779/1836973455.py:3: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df[col] = df[col].replace(mapping)
# /tmp/ipykernel_2779/1836973455.py:3: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df[col] = df[col].replace(mapping)
# ...

# %%
df[bool_columns].head()
# Out:
#    Daytime/evening attendance  Displaced  Educational special needs  Debtor  \
# 0                           1          1                          0       0
# 1                           1          1                          0       0
# 2                           1          1                          0       0
# 3                           1          1                          0       0
# 4                           0          0                          0       0
#
#    Tuition fees up to date  Scholarship holder  International
# 0                        1                   0              0
# 1                        0                   0              0
# 2                        0                   0              0
# 3                        1                   0              0
# 4                        1                   0              0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4424 entries, 0 to 4423
# Data columns (total 36 columns):
#  #   Column                                          Non-Null Count  Dtype
# ---  ------                                          --------------  -----
#  0   Marital status                                  4406 non-null   category
#  1   Application mode                                4424 non-null   category
#  2   Application order                               4424 non-null   category
#  3   Course                                          4424 non-null   category
#  4   Daytime/evening attendance                      4424 non-null   int64
#  5   Previous qualification                          4424 non-null   category
#  6   Previous qualification (grade)                  4424 non-null   float64
#  7   Nacionality                                     4424 non-null   category
#  8   Mother's qualification                          4420 non-null   category
# ...

# %%
cols_corr = list(df.columns)
cols_corr.remove('Target')

# %% [markdown]
# Usuwam kolumny powielajace w wiekszosci ta sama informacje

# %%
df.drop(columns = ['Curricular units 1st sem (credited)', 'Curricular units 1st sem (enrolled)', 'Curricular units 1st sem (evaluations)', 'Curricular units 1st sem (approved)', 'Curricular units 1st sem (grade)', 'Curricular units 2nd sem (approved)'], inplace = True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4424 entries, 0 to 4423
# Data columns (total 30 columns):
#  #   Column                                          Non-Null Count  Dtype
# ---  ------                                          --------------  -----
#  0   Marital status                                  4406 non-null   category
#  1   Application mode                                4424 non-null   category
#  2   Application order                               4424 non-null   category
#  3   Course                                          4424 non-null   category
#  4   Daytime/evening attendance                      4424 non-null   int64
#  5   Previous qualification                          4424 non-null   category
#  6   Previous qualification (grade)                  4424 non-null   float64
#  7   Nacionality                                     4424 non-null   category
#  8   Mother's qualification                          4420 non-null   category
# ...

# %%
df.to_pickle('student_dropout_xgboost.pkl')
